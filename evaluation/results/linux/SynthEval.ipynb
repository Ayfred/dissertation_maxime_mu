# %%
#!pip install syntheval

# %%
import pandas as pd
import numpy as np

# %%
# Go to the /users/pgrad/mamu/Documents/first/ directory 
import os
os.chdir('/users/pgrad/mamu/Documents/first')

# %%
# Load datasets
original_data = pd.read_csv('./datasets/data.csv')
generated_data = pd.read_csv('./llama3-8b/results/synthetic_data_llama_3_8b.csv')
# Subset the datasets to the minimum length
#min_len = min(len(original_data), len(generated_data))
#original_data = original_data.iloc[:min_len]
#generated_data = generated_data.iloc[:min_len]

# %%
print(original_data.shape)
print(generated_data.shape)
# Out:
# (349, 10)
# (948, 10)

# %%
from syntheval import SynthEval

evaluator = SynthEval(original_data)
_ = evaluator.evaluate(generated_data, 'Disease', "full_eval")
# Out:
# SynthEval: inferred categorical columns...
# SynthEval: synthetic data read successfully
# Syntheval: pca:   6%|▌         | 1/17 [00:00<00:02,  7.59it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 from syntheval import SynthEval
#       3 evaluator = SynthEval(original_data)
# ----> 4 _ = evaluator.evaluate(generated_data, 'Disease', "full_eval")
#
# File ~/Documents/first/.venv/lib/python3.10/site-packages/syntheval/syntheval.py:141, in SynthEval.evaluate(self, synthetic_dataframe, analysis_target_var, presets_file, **kwargs)
#     138     continue
#     140 M = loaded_metrics[method](real_data, synt_data, hout_data, self.categorical_columns, self.numerical_columns, self.nn_dist, analysis_target_var, do_preprocessing=False, verbose=self.verbose)
# --> 141 raw_results[method] = M.evaluate(**evaluation_config[method])
#     143 string       = M.format_output()
#     144 extra_string = M.extra_formatted_output()
#
# File ~/Documents/first/.venv/lib/python3.10/site-packages/syntheval/metrics/utility/metric_principal_component_analysis.py:47, in PrincipalComponentAnalysis.evaluate(self, num_components)
#      44 f_scaled = StandardScaler().fit_transform(self.synt_data[self.num_cols])
#      46 pca = PCA(n_components=num_components)
# ---> 47 r_pca = pca.fit_transform(r_scaled)
#      48 f_pca = pca.transform(f_scaled)
#      50 labels = [ f"PC {i+1} ({var:.1f}%)" for i, var in enumerate(pca.explained_variance_ratio_ * 100)]
#
# File ~/Documents/first/.venv/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:433, in PCA.fit_transform(self, X, y)
#     411 def fit_transform(self, X, y=None):
#     412     """Fit the model with X and apply the dimensionality reduction on X.
#     413
#     414     Parameters
#    (...)
#     431     C-ordered array, use 'np.ascontiguousarray'.
#     432     """
# --> 433     U, S, Vt = self._fit(X)
#     434     U = U[:, : self.n_components_]
#     436     if self.whiten:
#     437         # X_new = X * V / S * sqrt(n_samples) = U * sqrt(n_samples)
#
# File ~/Documents/first/.venv/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:483, in PCA._fit(self, X)
#     481 # Call different fits for either full or truncated SVD
#     482 if self._fit_svd_solver == "full":
# --> 483     return self._fit_full(X, n_components)
#     484 elif self._fit_svd_solver in ["arpack", "randomized"]:
#     485     return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# File ~/Documents/first/.venv/lib/python3.10/site-packages/sklearn/decomposition/_pca.py:501, in PCA._fit_full(self, X, n_components)
#     497         raise ValueError(
#     498             "n_components='mle' is only supported if n_samples >= n_features"
#     499         )
#     500 elif not 0 <= n_components <= min(n_samples, n_features):
# --> 501     raise ValueError(
#     502         "n_components=%r must be between 0 and "
#     503         "min(n_samples, n_features)=%r with "
#     504         "svd_solver='full'" % (n_components, min(n_samples, n_features))
#     505     )
#     506 elif n_components >= 1:
#     507     if not isinstance(n_components, numbers.Integral):
#
# ValueError: n_components=2 must be between 0 and min(n_samples, n_features)=1 with svd_solver='full'
