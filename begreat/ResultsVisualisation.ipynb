# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('results/results.csv')

# print the number of rows 
print(df.shape[0])

plt.figure(figsize=(24, 10))
sns.countplot(x='Disease', data=df)
plt.title('Distribution of Diseases')
plt.xlabel('Disease')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# 349

# %%
symptoms = df[['Disease', 'Fever', 'Cough', 'Fatigue', 'Difficulty Breathing']]
symptoms = symptoms.replace({'Yes': 1, 'No': 0})

symptoms_melted = symptoms.melt(id_vars='Disease', var_name='Symptom', value_name='Presence')
heatmap_data = symptoms_melted.groupby(['Disease', 'Symptom']).Presence.sum().unstack()

plt.figure(figsize=(20, 20))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm')
plt.title('Heatmap of Symptoms Across Diseases')
plt.show()
# Out:
# /tmp/ipykernel_109124/122048608.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   symptoms = symptoms.replace({'Yes': 1, 'No': 0})
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_109124/122048608.py in <module>
#       3
#       4 symptoms_melted = symptoms.melt(id_vars='Disease', var_name='Symptom', value_name='Presence')
# ----> 5 heatmap_data = symptoms_melted.groupby(['Disease', 'Symptom']).Presence.sum().unstack()
#       6
#       7 plt.figure(figsize=(20, 20))
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3144             # _agg_general() returns. GH #31422
#    3145             with com.temp_setattr(self, "observed", True):
# -> 3146                 result = self._agg_general(
#    3147                     numeric_only=numeric_only,
#    3148                     min_count=min_count,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc, **kwargs)
#    1904         **kwargs,
#    1905     ):
# -> 1906         result = self._cython_agg_general(
#    1907             how=alias,
#    1908             alt=npfunc,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1996             return result
#    1997
# -> 1998         new_mgr = data.grouped_reduce(array_func)
#    1999         res = self._wrap_agged_manager(new_mgr)
#    2000         if how in ["idxmin", "idxmax"]:
#
# ~/.local/lib/python3.10/site-packages/pandas/core/internals/base.py in grouped_reduce(self, func)
#     365     def grouped_reduce(self, func):
#     366         arr = self.array
# --> 367         res = func(arr)
#     368         index = default_index(len(res))
#     369
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1971         def array_func(values: ArrayLike) -> ArrayLike:
#    1972             try:
# -> 1973                 result = self._grouper._cython_operation(
#    1974                     "aggregate",
#    1975                     values,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     829         ids, _, _ = self.group_info
#     830         ngroups = self.ngroups
# --> 831         return cy_op.cython_operation(
#     832             values=values,
#     833             axis=axis,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     548             )
#     549
# --> 550         return self._cython_op_ndim_compat(
#     551             values,
#     552             min_count=min_count,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     327             if result_mask is not None:
#     328                 result_mask = result_mask[None, :]
# --> 329             res = self._call_cython_op(
#     330                 values2d,
#     331                 min_count=min_count,
#
# ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     416                 "sum",
#     417             ]:
# --> 418                 func(
#     419                     out=result,
#     420                     counts=counts,
#
# groupby.pyx in pandas._libs.groupby.group_sum()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
