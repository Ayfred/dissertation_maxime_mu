# %%
#!pip install syntheval

# %%
import pandas as pd
import numpy as np

# %%
# Go to the /users/pgrad/mamu/Documents/first/ directory 
import os
#os.chdir('/users/pgrad/mamu/Documents/first')
os.chdir('D:/maxim/Dissertation/first')

# %%
# Load datasets
original_data = pd.read_csv('./datasets/data-ori.csv')
generated_data = pd.read_csv('./llama3-8b/results/synthetic_data_llama_3_8b_data_ori.csv')

# Subset the datasets to the minimum length
min_len = min(len(original_data), len(generated_data))
original_data = original_data.iloc[:min_len]
generated_data = generated_data.iloc[:min_len]

# %%
original_data
# Out:
#       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  \
# 0            35.1          11.8         4.65        6.3          310  25.4
# 1            43.5          14.8         5.39       12.7          334  27.5
# 2            33.5          11.3         4.74       13.2          305  23.8
# 3            39.1          13.7         4.98       10.5          366  27.5
# 4            30.9           9.9         4.23       22.1          333  23.4
# ...           ...           ...          ...        ...          ...   ...
# 4407         32.8          10.4         3.49        8.1           72  29.8
# 4408         33.7          10.8         3.67        6.7           70  29.4
# 4409         33.2          11.2         3.47        7.2          235  32.3
# 4410         31.5          10.4         3.15        9.1          187  33.0
# 4411         33.5          10.9         3.44        5.8          275  31.7
#
#       MCHC    MCV  AGE SEX SOURCE
# 0     33.6   75.5    1   F    out
# 1     34.0   80.7    1   F    out
# 2     33.7   70.7    1   F    out
# 3     35.0   78.5    1   F    out
# 4     32.0   73.0    1   M    out
# ...    ...    ...  ...  ..    ...
# 4407  31.7   94.0   92   F     in
# 4408  32.0   91.8   92   F     in
# 4409  33.7   95.7   93   F    out
# 4410  33.0  100.0   98   F     in
# 4411  32.5   97.4   99   F    out
#
# [4412 rows x 11 columns]

# %%
# print column names
print(original_data.columns)
# Out:
# Index(['HAEMATOCRIT', 'HAEMOGLOBINS', 'ERYTHROCYTE', 'LEUCOCYTE',
#        'THROMBOCYTE', 'MCH', 'MCHC', 'MCV', 'AGE', 'SEX', 'SOURCE'],
#       dtype='object')

# %%
print(original_data.shape)
print(generated_data.shape)
# Out:
# (4412, 11)
# (4412, 11)

# %%
# Separate the original into 80 20

original_data_train = original_data.iloc[:int(0.8 * len(original_data))]
original_data_test = original_data.iloc[int(0.8 * len(original_data)):]

# %%
from syntheval import SynthEval

evaluator = SynthEval(original_data_train)
_ = evaluator.evaluate(generated_data, 'SOURCE', "full_eval")
# Out:
# SynthEval: inferred categorical columns...
# SynthEval: synthetic data read successfully
# Syntheval: cls_acc:  59%|█████▉    | 10/17 [00:44<00:43,  6.25s/it]
# Error: AUROC metric did not run, analysis target variable did not have appropriate number levels (i.e. 2) or test data was not supplied!
# cls_acc: 100%|██████████| 5/5 [00:02<00:00,  2.11it/s]
# Syntheval: att_discl:  88%|████████▊ | 15/17 [01:06<00:11,  5.54s/it]
# Error: Membership inference attack metric did not run, holdout data was not supplied!
# Syntheval: att_discl: 100%|██████████| 17/17 [01:39<00:00,  5.88s/it]
# SynthEval results
# =================================================================
#
# Utility metric description                    value   error
# +---------------------------------------------------------------+
# | Average dimensionwise means diff. (nums) :   0.0266  0.0009   |
# | PCA difference in eigenvalues (exp. var.):   0.0781           |
# | PCA angle between eigenvectors (radians) :   0.9489           |
# | Average confidence interval overlap      :   0.0300  0.0300   |
# |   -> # non-overlapping COIs at 95%       :    8               |
# |   -> fraction of non-overlapping CIs     :   0.8889           |
# | Mixed correlation matrix difference      :   1.0608           |
# | Pairwise mutual information difference   :   0.1937           |
# | Kolmogorov–Smirnov / Total Variation Distance test            |
# |   -> average combined statistic          :   0.0863  0.0174   |
# |       -> avg. Kolmogorov–Smirnov dist.   :   0.0974  0.0193   |
# |       -> avg. Total Variation Distance   :   0.0362  0.0121   |
# |   -> average combined p-value            :   0.0031  0.0029   |
# |       -> # significant tests at a=0.05   :   11               |
# |       -> fraction of significant tests   :   1.0000           |
# | Average empirical Hellinger distance     :   0.0775  0.0288   |
# | Propensity mean squared error (pMSE)     :   0.0168  0.0004   |
# |   -> average pMSE classifier accuracy    :   0.5442  0.0072   |
# | Nearest neighbour adversarial accuracy   :   0.9280  0.0000   |
# +---------------------------------------------------------------+
#
# Classification accuracy test
# avg. of 5-fold cross val.:
# classifier model             acc_r   acc_f    |diff|  error
# +---------------------------------------------------------------+
# | DecisionTreeClassifier  :   0.6421  0.5834   0.0586  0.0299   |
# | AdaBoostClassifier      :   0.7285  0.6661   0.0624  0.0585   |
# | RandomForestClassifier  :   0.7059  0.6475   0.0584  0.0177   |
# | LogisticRegression      :   0.7138  0.6812   0.0326  0.0317   |
# +---------------------------------------------------------------+
# | Average                 :   0.6976  0.6446   0.0530  0.0188   |
# +---------------------------------------------------------------+
#
# Privacy metric description                    value   error
# +---------------------------------------------------------------+
# | Nearest neighbour distance ratio         :   0.0437  0.0032   |
# | Median distance to closest record        :   1.5819           |
# | Hitting rate (0.03 x range(att))         :   0.0000           |
# | Epsilon identifiability risk             :   0.1729           |
# | Attr. disclosure risk (accuracy)         :   0.3977  0.1057   |
# +---------------------------------------------------------------+
